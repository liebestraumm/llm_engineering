# %% [markdown]
# # RAG Day 4
#
# ## Evaluation!
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Keep in mind how you would evaluate RAG for your business</h2>
#             <span style="color:#181;">This is such an important part of building an accurate and reliable RAG pipeline. And it's applicable to many aspects of solving business problems with LLMs. People are often focused on RAG architecture and RAG frameworks for their business. But even more important: evaluations!</span>
#         </td>
#     </tr>
# </table>

# %%
from evaluation import test

# %%
pip install litellm
# Out:
# Requirement already satisfied: litellm in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (1.85.0)
# Requirement already satisfied: fastuuid<1.0,>=0.14.0 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from litellm) (0.14.0)
# Requirement already satisfied: httpx<1.0,>=0.28.0 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from litellm) (0.28.1)
# Requirement already satisfied: openai<3.0.0,>=2.20.0 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from litellm) (2.37.0)
# Requirement already satisfied: python-dotenv<2.0,>=1.0.0 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from litellm) (1.1.0)
# Requirement already satisfied: tiktoken<1.0,>=0.8.0 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from litellm) (0.12.0)
# Requirement already satisfied: importlib-metadata<9.0,>=8.0.0 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from litellm) (8.4.0)
# Requirement already satisfied: tokenizers<1.0,>=0.21.0 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from litellm) (0.22.2)
# Requirement already satisfied: click<9.0,>=8.0.0 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from litellm) (8.1.8)
# Requirement already satisfied: jinja2<4.0,>=3.1.6 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from litellm) (3.1.6)
# Requirement already satisfied: aiohttp<4.0,>=3.10 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from litellm) (3.13.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.10.0 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from litellm) (2.11.3)
# Requirement already satisfied: jsonschema<5.0,>=4.0.0 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from litellm) (4.26.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from aiohttp<4.0,>=3.10->litellm) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from aiohttp<4.0,>=3.10->litellm) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from aiohttp<4.0,>=3.10->litellm) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from aiohttp<4.0,>=3.10->litellm) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from aiohttp<4.0,>=3.10->litellm) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from aiohttp<4.0,>=3.10->litellm) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from aiohttp<4.0,>=3.10->litellm) (1.22.0)
# Requirement already satisfied: anyio in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from httpx<1.0,>=0.28.0->litellm) (4.9.0)
# Requirement already satisfied: certifi in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from httpx<1.0,>=0.28.0->litellm) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from httpx<1.0,>=0.28.0->litellm) (1.0.8)
# Requirement already satisfied: idna in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from httpx<1.0,>=0.28.0->litellm) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1.0,>=0.28.0->litellm) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from importlib-metadata<9.0,>=8.0.0->litellm) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from jinja2<4.0,>=3.1.6->litellm) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from jsonschema<5.0,>=4.0.0->litellm) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from jsonschema<5.0,>=4.0.0->litellm) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from jsonschema<5.0,>=4.0.0->litellm) (0.30.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from openai<3.0.0,>=2.20.0->litellm) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from openai<3.0.0,>=2.20.0->litellm) (0.12.0)
# Requirement already satisfied: sniffio in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from openai<3.0.0,>=2.20.0->litellm) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from openai<3.0.0,>=2.20.0->litellm) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from openai<3.0.0,>=2.20.0->litellm) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.10.0->litellm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.10.0->litellm) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.10.0->litellm) (0.4.0)
# Requirement already satisfied: regex>=2022.1.18 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from tiktoken<1.0,>=0.8.0->litellm) (2026.1.15)
# Requirement already satisfied: requests>=2.26.0 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from tiktoken<1.0,>=0.8.0->litellm) (2.32.5)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from tokenizers<1.0,>=0.21.0->litellm) (1.3.5)
# Requirement already satisfied: filelock in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (2025.3.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (1.2.0)
# Requirement already satisfied: packaging>=20.9 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (6.0.2)
# Requirement already satisfied: shellingham in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (1.5.4)
# Requirement already satisfied: typer-slim in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (0.21.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from requests>=2.26.0->tiktoken<1.0,>=0.8.0->litellm) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/carlos/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages (from requests>=2.26.0->tiktoken<1.0,>=0.8.0->litellm) (2.4.0)
#
# [notice] A new release of pip is available: 26.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
tests = test.load_tests()

# %%
len(tests)
tests[0].question
# Out:
# 'Who won the prestigious IIOTY award in 2023?'

# %%
example = tests[0]
print(example.question)
print(example.category)
print(example.reference_answer)
print(example.keywords)
# Out:
# Who won the prestigious IIOTY award in 2023?
# direct_fact
# Maxine Thompson won the prestigious Insurellm Innovator of the Year (IIOTY) award in 2023.
# ['Maxine', 'Thompson', 'IIOTY']

# %%
from collections import Counter
count = Counter([t.category for t in tests])
count
# Out:
# Counter({'direct_fact': 70,
#          'temporal': 20,
#          'spanning': 20,
#          'comparative': 10,
#          'numerical': 10,
#          'relationship': 10,
#          'holistic': 10})

# %%
from evaluation.eval import evaluate_retrieval, evaluate_answer

# %%
evaluate_retrieval(example)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 evaluate_retrieval(example)
#
# File ~/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/week5/evaluation/eval.py:92, in evaluate_retrieval(test, k)
#      81 """
#      82 Evaluate retrieval performance for a test question.
#      83
#    (...)
#      89     RetrievalEval object with MRR, nDCG, and keyword coverage metrics
#      90 """
#      91 # Retrieve documents using shared answer module
# ---> 92 retrieved_docs = fetch_context(test.question)
#      94 # Calculate MRR (average across all keywords)
#      95 mrr_scores = [calculate_mrr(keyword, retrieved_docs) for keyword in test.keywords]
#
# File ~/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/week5/implementation/answer.py:38, in fetch_context(question)
#      34 def fetch_context(question: str) -> list[Document]:
#      35     """
#      36     Retrieve relevant context documents for a question.
#      37     """
# ---> 38     return retriever.invoke(question, k=RETRIEVAL_K)
#
# File ~/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages/langchain_core/retrievers.py:222, in BaseRetriever.invoke(self, input, config, **kwargs)
#     220 kwargs_ = kwargs if self._expects_other_args else {}
#     221 if self._new_arg_supported:
# --> 222     result = self._get_relevant_documents(
#     223         input, run_manager=run_manager, **kwargs_
#     224     )
#     225 else:
#     226     result = self._get_relevant_documents(input, **kwargs_)
#
# File ~/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages/langchain_core/vectorstores/base.py:1045, in VectorStoreRetriever._get_relevant_documents(self, query, run_manager, **kwargs)
#    1043 kwargs_ = self.search_kwargs | kwargs
#    1044 if self.search_type == "similarity":
# -> 1045     docs = self.vectorstore.similarity_search(query, **kwargs_)
#    1046 elif self.search_type == "similarity_score_threshold":
#    1047     docs_and_similarities = (
#    1048         self.vectorstore.similarity_search_with_relevance_scores(
#    1049             query, **kwargs_
#    1050         )
#    1051     )
#
# File ~/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages/langchain_chroma/vectorstores.py:748, in Chroma.similarity_search(self, query, k, filter, **kwargs)
#     730 def similarity_search(
#     731     self,
#     732     query: str,
#    (...)
#     735     **kwargs: Any,
#     736 ) -> list[Document]:
#     737     """Run similarity search with Chroma.
#     738
#     739     Args:
#    (...)
#     746         List of documents most similar to the query text.
#     747     """
# --> 748     docs_and_scores = self.similarity_search_with_score(
#     749         query,
#     750         k,
#     751         filter=filter,
#     752         **kwargs,
#     753     )
#     754     return [doc for doc, _ in docs_and_scores]
#
# File ~/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages/langchain_chroma/vectorstores.py:849, in Chroma.similarity_search_with_score(self, query, k, filter, where_document, **kwargs)
#     847 else:
#     848     query_embedding = self._embedding_function.embed_query(query)
# --> 849     results = self.__query_collection(
#     850         query_embeddings=[query_embedding],
#     851         n_results=k,
#     852         where=filter,
#     853         where_document=where_document,
#     854         **kwargs,
#     855     )
#     857 return _results_to_docs_and_scores(results)
#
# File ~/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages/langchain_core/utils/utils.py:51, in xor_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      45     msg = (
#      46         "Exactly one argument in each of the following"
#      47         " groups must be defined:"
#      48         f" {', '.join(invalid_group_names)}"
#      49     )
#      50     raise ValueError(msg)
# ---> 51 return func(*args, **kwargs)
#
# File ~/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages/langchain_chroma/vectorstores.py:477, in Chroma.__query_collection(self, query_texts, query_embeddings, n_results, where, where_document, **kwargs)
#     449 @xor_args(("query_texts", "query_embeddings"))
#     450 def __query_collection(
#     451     self,
#    (...)
#     457     **kwargs: Any,
#     458 ) -> list[Document] | chromadb.QueryResult:
#     459     """Query the chroma collection.
#     460
#     461     Args:
#    (...)
#     475     See more: https://docs.trychroma.com/reference/py-collection#query
#     476     """
# --> 477     return self._collection.query(
#     478         query_texts=query_texts,
#     479         query_embeddings=query_embeddings,  # type: ignore[arg-type]
#     480         n_results=n_results,
#     481         where=where,  # type: ignore[arg-type]
#     482         where_document=where_document,  # type: ignore[arg-type]
#     483         **kwargs,
#     484     )
#
# File ~/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages/chromadb/api/models/Collection.py:247, in Collection.query(self, query_embeddings, query_texts, query_images, query_uris, ids, n_results, where, where_document, include)
#     211 """Get the n_results nearest neighbor embeddings for provided query_embeddings or query_texts.
#     212
#     213 Args:
#    (...)
#     232
#     233 """
#     235 query_request = self._validate_and_prepare_query_request(
#     236     query_embeddings=query_embeddings,
#     237     query_texts=query_texts,
#    (...)
#     244     include=include,
#     245 )
# --> 247 query_results = self._client._query(
#     248     collection_id=self.id,
#     249     ids=query_request["ids"],
#     250     query_embeddings=query_request["embeddings"],
#     251     n_results=query_request["n_results"],
#     252     where=query_request["where"],
#     253     where_document=query_request["where_document"],
#     254     include=query_request["include"],
#     255     tenant=self.tenant,
#     256     database=self.database,
#     257 )
#     259 return self._transform_query_response(
#     260     response=query_results, include=query_request["include"]
#     261 )
#
# File ~/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages/chromadb/api/rust.py:550, in RustBindingsAPI._query(self, collection_id, query_embeddings, ids, n_results, where, where_document, include, tenant, database)
#     534 filtered_ids_amount = len(ids) if ids else 0
#     535 self.product_telemetry_client.capture(
#     536     CollectionQueryEvent(
#     537         collection_uuid=str(collection_id),
#    (...)
#     547     )
#     548 )
# --> 550 rust_response = self.bindings.query(
#     551     str(collection_id),
#     552     ids,
#     553     query_embeddings,
#     554     n_results,
#     555     json.dumps(where) if where else None,
#     556     json.dumps(where_document) if where_document else None,
#     557     include,
#     558     tenant,
#     559     database,
#     560 )
#     562 return QueryResult(
#     563     ids=rust_response.ids,
#     564     embeddings=rust_response.embeddings,
#    (...)
#     570     distances=rust_response.distances,
#     571 )
#
# InvalidArgumentError: Collection expecting embedding with dimension of 384, got 3072

# %%
eval, answer, chunks = evaluate_answer(example)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 eval, answer, chunks = evaluate_answer(example)
#
# File ~/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/week5/evaluation/eval.py:127, in evaluate_answer(test)
#     117 """
#     118 Evaluate answer quality using LLM-as-a-judge (async).
#     119
#    (...)
#     124     Tuple of (AnswerEval object, generated_answer string, retrieved_docs list)
#     125 """
#     126 # Get RAG response using shared answer module
# --> 127 generated_answer, retrieved_docs = answer_question(test.question)
#     129 # LLM judge prompt
#     130 judge_messages = [
#     131     {
#     132         "role": "system",
#    (...)
#     152     },
#     153 ]
#
# File ~/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/week5/implementation/answer.py:54, in answer_question(question, history)
#      50 """
#      51 Answer the given question with RAG; return the answer and the context documents.
#      52 """
#      53 combined = combined_question(question, history)
# ---> 54 docs = fetch_context(combined)
#      55 context = "\n\n".join(doc.page_content for doc in docs)
#      56 system_prompt = SYSTEM_PROMPT.format(context=context)
#
# File ~/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/week5/implementation/answer.py:38, in fetch_context(question)
#      34 def fetch_context(question: str) -> list[Document]:
#      35     """
#      36     Retrieve relevant context documents for a question.
#      37     """
# ---> 38     return retriever.invoke(question, k=RETRIEVAL_K)
#
# File ~/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages/langchain_core/retrievers.py:222, in BaseRetriever.invoke(self, input, config, **kwargs)
#     220 kwargs_ = kwargs if self._expects_other_args else {}
#     221 if self._new_arg_supported:
# --> 222     result = self._get_relevant_documents(
#     223         input, run_manager=run_manager, **kwargs_
#     224     )
#     225 else:
#     226     result = self._get_relevant_documents(input, **kwargs_)
#
# File ~/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages/langchain_core/vectorstores/base.py:1045, in VectorStoreRetriever._get_relevant_documents(self, query, run_manager, **kwargs)
#    1043 kwargs_ = self.search_kwargs | kwargs
#    1044 if self.search_type == "similarity":
# -> 1045     docs = self.vectorstore.similarity_search(query, **kwargs_)
#    1046 elif self.search_type == "similarity_score_threshold":
#    1047     docs_and_similarities = (
#    1048         self.vectorstore.similarity_search_with_relevance_scores(
#    1049             query, **kwargs_
#    1050         )
#    1051     )
#
# File ~/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages/langchain_chroma/vectorstores.py:748, in Chroma.similarity_search(self, query, k, filter, **kwargs)
#     730 def similarity_search(
#     731     self,
#     732     query: str,
#    (...)
#     735     **kwargs: Any,
#     736 ) -> list[Document]:
#     737     """Run similarity search with Chroma.
#     738
#     739     Args:
#    (...)
#     746         List of documents most similar to the query text.
#     747     """
# --> 748     docs_and_scores = self.similarity_search_with_score(
#     749         query,
#     750         k,
#     751         filter=filter,
#     752         **kwargs,
#     753     )
#     754     return [doc for doc, _ in docs_and_scores]
#
# File ~/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages/langchain_chroma/vectorstores.py:849, in Chroma.similarity_search_with_score(self, query, k, filter, where_document, **kwargs)
#     847 else:
#     848     query_embedding = self._embedding_function.embed_query(query)
# --> 849     results = self.__query_collection(
#     850         query_embeddings=[query_embedding],
#     851         n_results=k,
#     852         where=filter,
#     853         where_document=where_document,
#     854         **kwargs,
#     855     )
#     857 return _results_to_docs_and_scores(results)
#
# File ~/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages/langchain_core/utils/utils.py:51, in xor_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      45     msg = (
#      46         "Exactly one argument in each of the following"
#      47         " groups must be defined:"
#      48         f" {', '.join(invalid_group_names)}"
#      49     )
#      50     raise ValueError(msg)
# ---> 51 return func(*args, **kwargs)
#
# File ~/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages/langchain_chroma/vectorstores.py:477, in Chroma.__query_collection(self, query_texts, query_embeddings, n_results, where, where_document, **kwargs)
#     449 @xor_args(("query_texts", "query_embeddings"))
#     450 def __query_collection(
#     451     self,
#    (...)
#     457     **kwargs: Any,
#     458 ) -> list[Document] | chromadb.QueryResult:
#     459     """Query the chroma collection.
#     460
#     461     Args:
#    (...)
#     475     See more: https://docs.trychroma.com/reference/py-collection#query
#     476     """
# --> 477     return self._collection.query(
#     478         query_texts=query_texts,
#     479         query_embeddings=query_embeddings,  # type: ignore[arg-type]
#     480         n_results=n_results,
#     481         where=where,  # type: ignore[arg-type]
#     482         where_document=where_document,  # type: ignore[arg-type]
#     483         **kwargs,
#     484     )
#
# File ~/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages/chromadb/api/models/Collection.py:247, in Collection.query(self, query_embeddings, query_texts, query_images, query_uris, ids, n_results, where, where_document, include)
#     211 """Get the n_results nearest neighbor embeddings for provided query_embeddings or query_texts.
#     212
#     213 Args:
#    (...)
#     232
#     233 """
#     235 query_request = self._validate_and_prepare_query_request(
#     236     query_embeddings=query_embeddings,
#     237     query_texts=query_texts,
#    (...)
#     244     include=include,
#     245 )
# --> 247 query_results = self._client._query(
#     248     collection_id=self.id,
#     249     ids=query_request["ids"],
#     250     query_embeddings=query_request["embeddings"],
#     251     n_results=query_request["n_results"],
#     252     where=query_request["where"],
#     253     where_document=query_request["where_document"],
#     254     include=query_request["include"],
#     255     tenant=self.tenant,
#     256     database=self.database,
#     257 )
#     259 return self._transform_query_response(
#     260     response=query_results, include=query_request["include"]
#     261 )
#
# File ~/Documents/UDEMY/AI/LLM ENGINEERING/COURSE ORIGINAL CODE FORK/.venv/lib/python3.13/site-packages/chromadb/api/rust.py:550, in RustBindingsAPI._query(self, collection_id, query_embeddings, ids, n_results, where, where_document, include, tenant, database)
#     534 filtered_ids_amount = len(ids) if ids else 0
#     535 self.product_telemetry_client.capture(
#     536     CollectionQueryEvent(
#     537         collection_uuid=str(collection_id),
#    (...)
#     547     )
#     548 )
# --> 550 rust_response = self.bindings.query(
#     551     str(collection_id),
#     552     ids,
#     553     query_embeddings,
#     554     n_results,
#     555     json.dumps(where) if where else None,
#     556     json.dumps(where_document) if where_document else None,
#     557     include,
#     558     tenant,
#     559     database,
#     560 )
#     562 return QueryResult(
#     563     ids=rust_response.ids,
#     564     embeddings=rust_response.embeddings,
#    (...)
#     570     distances=rust_response.distances,
#     571 )
#
# InvalidArgumentError: Collection expecting embedding with dimension of 384, got 3072

# %%
eval
# Out:
# AnswerEval(feedback="The answer correctly identifies Maxine as the winner and mentions the IIOTY award in 2023, but it omits Thompson's full name, which is present in the reference. This affects completeness. The relevance is high, as it directly addresses the question about the award winner.", accuracy=5.0, completeness=4.0, relevance=5.0)

# %%
print(eval.feedback)
print(eval.accuracy)
print(eval.completeness)
print(eval.relevance)
# Out:
# The answer correctly identifies Maxine as the winner and mentions the IIOTY award in 2023, but it omits Thompson's full name, which is present in the reference. This affects completeness. The relevance is high, as it directly addresses the question about the award winner.
# 5.0
# 4.0
# 5.0
